# %% [markdown]
# <a href="https://colab.research.google.com/github/lacrespoc/ucv-si-lab06-lcm/blob/main/Grafo02_S6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt
#crear un grafo vacío
G = nx.Graph()

#Agregar nodos al grafo
G.add_node("Padre")
G.add_node("Hijo 1")
G.add_node("Hijo 2")

#Agregar conexiones entre nodos
G.add_edge("Padre", "Hijo 1")
G.add_edge("Padre", "Hijo 2")

#Dibujar el grafo
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True)

#Mostrar el grafo
plt.show()
